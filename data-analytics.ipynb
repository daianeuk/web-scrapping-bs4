# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('olympics.csv',  sep=',', encoding='latin-1')
df
# Out:
#                                                pais  jogos_verao  ouro  prata  \
# 0                                   AFG Afeganistão           14     0      0
# 1                                 RSA África do Sul           20    27     33
# 2                                GER Alemanha[3][4]           17   201    205
# 3                          GDR Alemanha Oriental[5]            5   153    129
# 4                      FRG Alemanha Ocidental[3][5]            5    56     67
# ..                                              ...          ...   ...    ...
# 151                                      ZAM Zâmbia           14     0      1
# 152                                    ZIM Zimbabwe           14     3      4
# 153                            ZZX Equipa mista[31]            3     8      5
# 154        IOA Atletas Olímpicos Independentes[IOA]            3     1      0
# 155  IOP Participantes Olímpicos Independentes[IOP]            1     0      1
#
# ...
